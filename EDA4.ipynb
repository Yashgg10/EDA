# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashgg10/EDA/blob/main/EDA4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('spotify.csv')
df
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Artist         440 non-null    object
#  1   Track Name     440 non-null    object
#  2   Popularity     440 non-null    int64
#  3   Duration (ms)  440 non-null    int64
#  4   Track ID       440 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 17.3+ KB

# %%
df.isnull().sum()
# Out:
# Artist           0
# Track Name       0
# Popularity       0
# Duration (ms)    0
# Track ID         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 27

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 413 entries, 0 to 438
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Artist         413 non-null    object
#  1   Track Name     413 non-null    object
#  2   Popularity     413 non-null    int64
#  3   Duration (ms)  413 non-null    int64
#  4   Track ID       413 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 19.4+ KB

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 408  French Montana                                       Stand United
# 409    Jason Derulo                     Tip Toe (feat. French Montana)
# 410         Fat Joe                     All The Way Up (feat. Infared)
# 411       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 412           Diddy                Another One Of Me (feat. 21 Savage)
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Artist         413 non-null    object
#  1   Track Name     413 non-null    object
#  2   Popularity     413 non-null    int64
#  3   Duration (ms)  413 non-null    int64
#  4   Track ID       413 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 16.3+ KB

# %%
# What is the distribution of popularity among the tracks in the dataset? Visualize it using a histogram
sns.histplot(df['Popularity'], kde=True)
plt.title('Distribution of Popularity')
plt.xlabel('Popularity')
plt.show()

# %%
df[['Popularity', 'Duration (ms)']].corr()
# Out:
#                Popularity  Duration (ms)
# Popularity       1.000000       0.038992
# Duration (ms)    0.038992       1.000000

# %%
sns.scatterplot(x='Popularity', y='Duration (ms)', data=df)
plt.title('Popularity vs Duration')
plt.show()

# %%
df['Artist'].value_counts().sort_values(ascending=False)
# Out:
# Artist
# Drake            17
# Eminem           11
# Flo Rida         10
# Ludacris         10
# Timbaland        10
#                  ..
# The Kid LAROI     1
# Dr. Dre           1
# NEIKED            1
# Young Nudy        1
# Diddy             1
# Name: count, Length: 115, dtype: int64

# %%
# Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist using a countplot
plt.figure(figsize=(20, 6))
sns.countplot(x='Artist', data=df)
plt.title('Count of Tracks by Artist')
plt.xticks(rotation=90)
plt.show()

# %%
#  What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each
df['Popularity'].sort_values(ascending=True).head(5)
# Out:
# 199    29
# 219    35
# 390    44
# 213    47
# 384    48
# Name: Popularity, dtype: int64

# %%
df['Popularity'].sort_values(ascending=True).head(5).values
# Out:
# array([29, 35, 44, 47, 48])

# %%
for pop in df['Popularity']:
  if pop in df['Popularity'].sort_values(ascending=True).head(5).values:
    print(df[df['Popularity'] == pop][['Artist', 'Track Name']])
# Out:
#      Artist                     Track Name
# 199  Pressa  Attachments (feat. Coi Leray)
#        Artist     Track Name
# 213  Lil Baby  On Me - Remix
#             Artist  Track Name
# 219  Justin Bieber  Intentions
#           Artist                 Track Name
# 384  Wyclef Jean  911 (feat. Mary J. Blige)
#              Artist       Track Name
# 390  French Montana  Splash Brothers

# %%
popular_artist = df.groupby('Artist')['Popularity'].sum().sort_values(ascending=False).head()
popular_artist
# Out:
# Artist
# Drake        1409
# Eminem        920
# ¥$            851
# 21 Savage     838
# Flo Rida      780
# Name: Popularity, dtype: int64

# %%
for artist in popular_artist.index:
  print(artist, df[df['Artist'] == artist]['Popularity'].mean())
# Out:
# Drake 82.88235294117646
# Eminem 83.63636363636364
# ¥$ 85.1
# 21 Savage 83.8
# Flo Rida 78.0

# %%
df.groupby('Artist')['Popularity'].mean().sort_values(ascending=False)
# Out:
# Artist
# cassö             92.000000
# Trueno            89.000000
# David Guetta      87.000000
# Travis Scott      86.555556
# ¥$                85.100000
#                     ...
# RAYE              55.000000
# Wyclef Jean       54.500000
# Arizona Zervas    54.000000
# Justin Bieber     49.000000
# Pressa            29.000000
# Name: Popularity, Length: 115, dtype: float64

# %%
df['Popularity'].sort_values(ascending=False).head(5)
# Out:
# 39     97
# 68     96
# 247    96
# 30     93
# 134    92
# Name: Popularity, dtype: int64

# %%
# For the top 5 most popular artists, what are their most popular tracks? List the track name for each artis
for artist in popular_artist.index:
  print(artist, df[df['Artist'] == artist].sort_values(by='Popularity', ascending=False).head(1)['Track Name'].values[0])
# Out:
# Drake Rich Baby Daddy (feat. Sexyy Red & SZA)
# Eminem Without Me
# ¥$ CARNIVAL
# 21 Savage redrum
# Flo Rida Low (feat. T-Pain)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Artist         413 non-null    object
#  1   Track Name     413 non-null    object
#  2   Popularity     413 non-null    int64
#  3   Duration (ms)  413 non-null    int64
#  4   Track ID       413 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 16.3+ KB

# %%
sns.pairplot(df)

# %%
# Does the duration of tracks vary significantly across different artists? Explore this visually using a box plot or violin plot
plt.figure(figsize=(20, 6))
sns.boxplot(x='Artist', y='Duration (ms)', data=df)
plt.title('Duration of Tracks by Artist')
plt.xticks(rotation=90)
plt.show()

# %%
#  How does the distribution of track popularity vary for different artists? Visualize this using a swarm plot or a violin plot
plt.figure(figsize=(20, 6))
sns.violinplot(x='Artist', y='Popularity', data=df)
plt.title('Distribution of Track Popularity by Artist')
plt.xticks(rotation=90)
plt.show()
